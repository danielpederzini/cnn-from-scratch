# %%
import numpy as np
from utils.data_loader import ImagenetteDataLoader

# %%
train_loader = ImagenetteDataLoader(
    root_path='notebooks/input/imagenette2',
    split='train',
    target_size=(224, 224)
)

images, labels = train_loader.load_images()
images.shape, labels.shape
# Out:
# ((9469, 3, 224, 224), (9469,))

# %%
random_indices = np.random.randint(0, len(images), size=20)
train_loader.plot_batch(random_indices, figsize=(10, 10))
